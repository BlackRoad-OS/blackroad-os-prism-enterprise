# %% [markdown]
# # Qiskit Hardware Roundtrip

# %%
from quantum_lab.core.circuit import Circuit
from quantum_lab.qiskit_backend.run import build_qiskit_circuit
circuit = Circuit(1)
circuit.add('H', targets=[0])
qc = build_qiskit_circuit(circuit)
qc
