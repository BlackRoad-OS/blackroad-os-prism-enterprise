# %% [markdown]
# # Noise and Mitigation

# %%
from quantum_lab.core.noise import depolarizing_channel, apply_kraus_channel
from quantum_lab.core.states import plus_state
state = plus_state()
noisy = apply_kraus_channel(depolarizing_channel(0.1), state)
noisy
