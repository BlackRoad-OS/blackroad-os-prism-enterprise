# %% [markdown]
# # Demo: Demo Codegen

# %%
from qlm_lab.orchestrator import Orchestrator
orch = Orchestrator()
result = orch.run_goal('demo_codegen')
for report in result.reports:
    print(report)
